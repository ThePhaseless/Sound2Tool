# %%
## https : //github. con}/sdadas/polish-nlp-resources?tab=readme-ov-file#word2vec
##! pip install transformers
from transformers import pipeline

seed_text1="na stronę liberalizmu były dwa odcienie liberalizmu umiarkowany i radykalny chcący przeprowadzić zasadniczą reformę konstytucji"

generator = pipeline ("text-generation", model="sdadas/polish-gpt2-medium")
results = generator (seed_text1,
    max_new_tokens=50, do_sample=True, repetition_penalty = 1.2, 
    num_return_sequences=1, num_beams=1, temperature=0.95,top_k=50, top_p=0.95)

print(results)
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# [{'generated_text': 'na stronę liberalizmu były dwa odcienie liberalizmu umiarkowany i radykalny chcący przeprowadzić zasadniczą reformę konstytucji. Jednym z jego przedstawicieli był Leon Festinger - konserwatywny liberał, ale zwolennik demokracji bezpośredniej (tzw. prawo Gaëtanego), które miało doprowadzić do decentralizacji państwa na poziomie lokalnym. Z drugiej strony była to polityka anty'}]
